# %%
#Load data from a CSV file on the web or file path
import pandas as pd
file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'
df = pd.read_csv(file_path)
df
# Out:
#           Timestamp     Operating System  CPU Cycle Rate (in GHz)  \
# 0   6/13/2023 13:21              Windows                      3.0
# 1   6/13/2023 13:23  I use Mac and Linux                   2133.0
# 2   6/13/2023 13:24                MacOS                      3.2
# 3   6/13/2023 13:25                MacOS                      3.6
# 4   6/13/2023 13:25              Windows                      2.3
# ..              ...                  ...                      ...
# 57  6/13/2023 13:45              Windows                      2.5
# 58  6/13/2023 13:45                MacOS                      2.3
# 59  6/13/2023 13:47                MacOS                      2.3
# 60  6/13/2023 13:49              Windows                      1.8
# 61  6/13/2023 13:52                MacOS                      2.3
#
#     CPU Number of Cores (int)  RAM (in GB)  Hard Drive Size (in GB)  \
# 0                           8           16                      935
# ...

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['Operating System'], bins=15)
plt.xlabel('Operating System')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - Operating System')
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['Hard Drive Size (in GB)'], bins=15)
plt.xlabel('Hard Drive Size (in GB)')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - Hard Drive')
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['CPU Cycle Rate (in GHz)'], bins=15)
plt.xlabel('CPU Cycle Rate (in GHz)')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - CPU Cycle Rate')
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['CPU Number of Cores (int)'], bins=15)
plt.xlabel('CPU Number of Cores (int)')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - CPU Number of Cores')
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['RAM (in GB)'], bins=15)
plt.xlabel('RAM (in GB)')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - RAM')
plt.show()

# %%
import pandas as pd

file_path = r'C:\Users\david\OneDrive\UVA\Orientation\2023-06-13-survey.csv'

#load the CSV file into a DataFrame
df = pd.read_csv(file_path)

plt.hist(df['GPU CUDA Number of Cores (int)'], bins=15)
plt.xlabel('GPU CUDA Number of Cores (int)')
plt.ylabel('Number of Students')
plt.title('2024 Survey Hardware Data - GPU CUDA')
plt.show()
